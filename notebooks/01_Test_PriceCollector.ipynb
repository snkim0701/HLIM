# %%
import sys

print(sys.executable)
# Out:
# C:\Users\snkim\AppData\Local\Programs\Python\Python313\python.exe

# %%
import pandas as pd
import yfinance as yf

print(pd.__version__)
print(yf.__version__)
# Out:
# 3.0.3
# 1.5.1

# %%
import pandas as pd

df = pd.read_csv("../data/raw/MU_price.csv")

print(df.head())

print(df.info())
# Out:
#         Price           Adj Close               Close               High  \
# 0      Ticker                  MU                  MU                 MU
# 1        Date                 NaN                 NaN                NaN
# 2  2015-01-02  33.886016845703125               34.75  35.52000045776367
# 3  2015-01-05  32.940128326416016  33.779998779296875   34.7400016784668
# 4  2015-01-06   32.05276107788086  32.869998931884766  34.22999954223633
#
#                   Low                Open    Volume
# 0                  MU                  MU        MU
# 1                 NaN                 NaN       NaN
# 2   34.34000015258789    35.2400016784668  15138200
# 3               33.75  34.709999084472656  23706600
# 4  32.630001068115234  34.099998474121094  40092000
# <class 'pandas.DataFrame'>
# RangeIndex: 2897 entries, 0 to 2896
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      2897 non-null   str
#  1   Adj Close  2896 non-null   str
#  2   Close      2896 non-null   str
#  3   High       2896 non-null   str
#  4   Low        2896 non-null   str
#  5   Open       2896 non-null   str
#  6   Volume     2896 non-null   str
# dtypes: str(7)
# memory usage: 158.6 KB
# None

# %%
df = pd.read_csv("../data/raw/MU_price.csv")

print(df.head())

print(df.info())
# Out:
#         Price           Adj Close               Close               High  \
# 0      Ticker                  MU                  MU                 MU
# 1        Date                 NaN                 NaN                NaN
# 2  2015-01-02  33.886016845703125               34.75  35.52000045776367
# 3  2015-01-05  32.940128326416016  33.779998779296875   34.7400016784668
# 4  2015-01-06   32.05276107788086  32.869998931884766  34.22999954223633
#
#                   Low                Open    Volume
# 0                  MU                  MU        MU
# 1                 NaN                 NaN       NaN
# 2   34.34000015258789    35.2400016784668  15138200
# 3               33.75  34.709999084472656  23706600
# 4  32.630001068115234  34.099998474121094  40092000
# <class 'pandas.DataFrame'>
# RangeIndex: 2897 entries, 0 to 2896
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      2897 non-null   str
#  1   Adj Close  2896 non-null   str
#  2   Close      2896 non-null   str
#  3   High       2896 non-null   str
#  4   Low        2896 non-null   str
#  5   Open       2896 non-null   str
#  6   Volume     2896 non-null   str
# dtypes: str(7)
# memory usage: 158.6 KB
# None

# %%
import os 
print(os.getcwd())
# Out:
# C:\Users\snkim\Desktop\Stock\GitStock\HLIM\notebooks

# %%
file = "../data/raw/MU_price.csv"

with open(file, "r") as f:
    for i in range(8):
        print(f.readline().strip())
# Out:
# Date,Adj Close,Close,High,Low,Open,Volume
# 2015-01-02,33.886009216308594,34.75,35.52000045776367,34.34000015258789,35.2400016784668,15138200
# 2015-01-05,32.94013595581055,33.779998779296875,34.7400016784668,33.75,34.709999084472656,23706600
# 2015-01-06,32.052764892578125,32.869998931884766,34.22999954223633,32.630001068115234,34.099998474121094,40092000
# 2015-01-07,31.301902770996094,32.099998474121094,32.97999954223633,31.450000762939453,31.530000686645508,52552300
# 2015-01-08,32.83286666870117,33.66999816894531,33.869998931884766,32.54999923706055,32.560001373291016,31947100
# 2015-01-09,32.696346282958984,33.529998779296875,33.869998931884766,32.959999084472656,33.7599983215332,19328500
# 2015-01-12,30.87284278869629,31.65999984741211,32.9900016784668,31.399999618530273,32.38999938964844,41982700

# %%
import pandas as pd

df = pd.read_csv("../data/raw/MU_price.csv")

print(df.head())
print()
print(df.info())
# Out:
#          Date  Adj Close      Close       High        Low       Open    Volume
# 0  2015-01-02  33.886009  34.750000  35.520000  34.340000  35.240002  15138200
# 1  2015-01-05  32.940136  33.779999  34.740002  33.750000  34.709999  23706600
# 2  2015-01-06  32.052765  32.869999  34.230000  32.630001  34.099998  40092000
# 3  2015-01-07  31.301903  32.099998  32.980000  31.450001  31.530001  52552300
# 4  2015-01-08  32.832867  33.669998  33.869999  32.549999  32.560001  31947100
#
# <class 'pandas.DataFrame'>
# RangeIndex: 2895 entries, 0 to 2894
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2895 non-null   str
#  1   Adj Close  2895 non-null   float64
#  2   Close      2895 non-null   float64
#  3   High       2895 non-null   float64
#  4   Low        2895 non-null   float64
#  5   Open       2895 non-null   float64
#  6   Volume     2895 non-null   int64
# dtypes: float64(5), int64(1), str(1)
# memory usage: 158.4 KB
# None

# %%
df["Date"] = pd.to_datetime(df["Date"])

print(df.dtypes)
# Out:
# Date         datetime64[us]
# Adj Close           float64
# Close               float64
# High                float64
# Low                 float64
# Open                float64
# Volume                int64
# dtype: object
